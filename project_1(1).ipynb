# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import ShuffleSplit
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
import seaborn as sns
from xgboost import plot_importance
from matplotlib import pyplot as plt
from sklearn.metrics import roc_auc_score

# %% [markdown]
# ### Data Processing

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv("test.csv")

# %%
from sklearn import preprocessing

X, Y = train.iloc[:, :-1], train.iloc[:, -1]

# %%
df = X
replace_dic = {' ?':'Unknown'}
df.select_dtypes(include=['object']).replace(replace_dic)
# Out:
#                           class_worker                    education  \
# 0                      Not in universe         High school graduate
# 1                              Private   Bachelors degree(BA AB BS)
# 2                              Private   Some college but no degree
# 3       Self-employed-not incorporated   Bachelors degree(BA AB BS)
# 4                      Not in universe                     Children
# ...                                ...                          ...
# 59763                          Private   Some college but no degree
# 59764                  Not in universe                     Children
# 59765                          Private   Some college but no degree
# 59766                          Private             5th or 6th grade
# 59767                  Not in universe                     Children
#
#              hs_college                      marital_stat  \
# 0       Not in universe                     Never married
# 1       Not in universe                     Never married
# 2       Not in universe   Married-civilian spouse present
# 3       Not in universe                          Divorced
# 4       Not in universe                     Never married
# ...                 ...                               ...
# 59763   Not in universe                     Never married
# 59764   Not in universe                     Never married
# 59765   Not in universe   Married-civilian spouse present
# 59766   Not in universe   Married-civilian spouse present
# 59767   Not in universe                     Never married
#
#                          major_ind_code  \
# 0           Not in universe or children
# 1       Utilities and sanitary services
# 2        Manufacturing-nondurable goods
# 3           Other professional services
# 4           Not in universe or children
# ...                                 ...
# 59763    Manufacturing-nondurable goods
# 59764       Not in universe or children
# 59765                      Retail trade
# 59766                      Retail trade
# 59767       Not in universe or children
#
#                                major_occ_code    race  \
# 0                             Not in universe   White
# 1              Adm support including clerical   White
# 2              Adm support including clerical   White
# 3                      Professional specialty   White
# 4                             Not in universe   White
# ...                                       ...     ...
# 59763   Machine operators assmblrs & inspctrs   White
# 59764                         Not in universe   White
# 59765                                   Sales   White
# 59766                           Other service   White
# 59767                         Not in universe   Other
#
#                       hisp_origin      sex      union_member  ...  \
# 0                       All other     Male   Not in universe  ...
# 1                       All other     Male   Not in universe  ...
# 2                       All other   Female   Not in universe  ...
# 3                       All other   Female   Not in universe  ...
# 4                       All other   Female   Not in universe  ...
# ...                           ...      ...               ...  ...
# 59763                   All other     Male   Not in universe  ...
# 59764                   All other     Male   Not in universe  ...
# 59765                   All other     Male   Not in universe  ...
# 59766          Mexican (Mexicano)     Male   Not in universe  ...
# 59767   Central or South American   Female   Not in universe  ...
#
#         mig_chg_reg  mig_move_reg                           mig_same  \
# 0           Unknown       Unknown   Not in universe under 1 year old
# 1          Nonmover      Nonmover                                Yes
# 2          Nonmover      Nonmover                                Yes
# 3           Unknown       Unknown   Not in universe under 1 year old
# 4       Same county   Same county                                 No
# ...             ...           ...                                ...
# 59763       Unknown       Unknown   Not in universe under 1 year old
# 59764       Unknown       Unknown   Not in universe under 1 year old
# 59765      Nonmover      Nonmover                                Yes
# 59766      Nonmover      Nonmover                                Yes
# 59767      Nonmover      Nonmover                                Yes
#
#        mig_prev_sunbelt           fam_under_18  country_father  \
# 0               Unknown        Not in universe   United-States
# 1       Not in universe        Not in universe   United-States
# 2       Not in universe        Not in universe   United-States
# 3               Unknown        Not in universe   United-States
# 4                    No   Both parents present   United-States
# ...                 ...                    ...             ...
# 59763           Unknown        Not in universe   United-States
# 59764           Unknown   Both parents present   United-States
# 59765   Not in universe        Not in universe   United-States
# 59766   Not in universe        Not in universe          Mexico
# 59767   Not in universe   Both parents present        Columbia
#
#        country_mother    country_self  \
# 0       United-States   United-States
# 1       United-States   United-States
# 2       United-States   United-States
# 3       United-States   United-States
# 4       United-States   United-States
# ...               ...             ...
# 59763   United-States   United-States
# 59764   United-States   United-States
# 59765   United-States   United-States
# 59766          Mexico          Mexico
# 59767        Columbia   United-States
#
#                                         citizenship      vet_question
# 0                 Native- Born in the United States   Not in universe
# 1                 Native- Born in the United States   Not in universe
# 2                 Native- Born in the United States   Not in universe
# 3                 Native- Born in the United States   Not in universe
# 4                 Native- Born in the United States   Not in universe
# ...                                             ...               ...
# 59763             Native- Born in the United States   Not in universe
# 59764             Native- Born in the United States   Not in universe
# 59765             Native- Born in the United States   Not in universe
# 59766   Foreign born- U S citizen by naturalization   Not in universe
# 59767             Native- Born in the United States   Not in universe
#
# [59768 rows x 28 columns]

# %%
# see if there are missing entries in the dataset features
categorical_columns = df.select_dtypes(include=['object']).columns
print('the number of categorical columns',len(categorical_columns))
print('the number of columns',len(X.columns))
X.isnull().sum().sort_values()
# Out:
# the number of categorical columns 28
# the number of columns 42
# id                  0
# det_hh_fam_stat     0
# det_hh_summ         0
# unknown             0
# mig_chg_msa         0
# mig_chg_reg         0
# mig_move_reg        0
# mig_same            0
# mig_prev_sunbelt    0
# num_emp             0
# fam_under_18        0
# country_father      0
# country_mother      0
# country_self        0
# citizenship         0
# own_or_self         0
# vet_question        0
# vet_benefits        0
# state_prev_res      0
# region_prev_res     0
# tax_filer_stat      0
# stock_dividends     0
# age                 0
# class_worker        0
# det_ind_code        0
# det_occ_code        0
# education           0
# wage_per_hour       0
# hs_college          0
# marital_stat        0
# weeks_worked        0
# major_ind_code      0
# race                0
# hisp_origin         0
# sex                 0
# union_member        0
# unemp_reason        0
# full_or_part_emp    0
# capital_gains       0
# capital_losses      0
# major_occ_code      0
# year                0
# dtype: int64

# %%
null_stat = X.isnull().sum()
null_variables_num = 0
null_categorical_v_n = 0
for i in range(len(X.columns)):
    if null_stat[i]>0:
        null_variables_num+=1
        if X.columns[i] in categorical_columns:
            null_categorical_v_n += 1
            
print('The number of variables containing null value:',null_variables_num)
print('The number of categorical variables containing null value:',null_categorical_v_n)
# Out:
# The number of variables containing null value: 0
# The number of categorical variables containing null value: 0

# %% [markdown]
# #### remove variables which contain missing values

# %%
clean_columns = []
for i in range(len(X.columns)):
    if null_stat[i]<=0.3:
        clean_columns.append(X.columns[i])

# %%
clean_X = X
from sklearn.preprocessing import LabelEncoder 
labelencoder= LabelEncoder() #initializing an object of class LabelEncoder
categorical_columns = clean_X.select_dtypes(include=['object']).columns
for categorical_column in categorical_columns:
    clean_X[categorical_column] = labelencoder.fit_transform(clean_X[categorical_column]) #fitting and transforming the desired categorical column.

# %%
clean_test_X = test
for categorical_column in categorical_columns:
    clean_test_X[categorical_column] = clean_test_X[categorical_column]
    clean_test_X[categorical_column] = labelencoder.fit_transform(clean_test_X[categorical_column]) #fitting and transforming the desired categorical column.

# %%
clean_test_X = clean_test_X.drop(columns=['id'])

# %%
clean_X['target'] = Y

# %%
# Corelation with target
x = clean_X.corr()
pd.DataFrame(x['target']).sort_values(by='target',ascending = False).style.background_gradient(cmap = 'Greens')
# Out:
# <style  type="text/css" >
#     #T_251e2826_3749_11ec_8222_784f4383c434row0_col0 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_251e2826_3749_11ec_8222_784f4383c434row1_col0 {
#             background-color:  #53b466;
#             color:  #000000;
#         }    #T_251e2826_3749_11ec_8222_784f4383c434row2_col0 {
#             background-color:  #6bc072;
#             color:  #000000;
#         }    #T_251e2826_3749_11ec_8222_784f4383c434row3_col0 {
#             background-color:  #79c67a;
#             color:  #000000;
#         }    #T_251e2826_3749_11ec_8222_784f4383c434row4_col0 {
#             background-color:  #87cd86;
#             color:  #000000;
#         }    #T_251e2826_3749_11ec_8222_784f4383c434row5_col0 {
#             background-color:  #8ace88;
#             color:  #000000;
#         }    #T_251e2826_3749_11ec_8222_784f4383c434row6_col0 {
#             background-color:  #8dd08a;
#             color:  #000000;
#         }    #T_251e2826_3749_11ec_8222_784f4383c434row7_col0 {
#             background-color:  #91d28e;
#             color:  #000000;
#         }    #T_251e2826_3749_11ec_8222_784f4383c434row8_col0 {
#             background-color:  #99d595;
#             color:  #000000;
#         }    #T_251e2826_3749_11ec_8222_784f4383c434row9_col0 {
#             background-color:  #a4da9e;
#             color:  #000000;
#         }    #T_251e2826_3749_11ec_8222_784f4383c434row10_col0 {
#             background-color:  #a7dba0;
#             color:  #000000;
#         }    #T_251e2826_3749_11ec_8222_784f4383c434row11_col0 {
#             background-color:  #a8dca2;
#             color:  #000000;
#         }    #T_251e2826_3749_11ec_8222_784f4383c434row12_col0 {
#             background-color:  #abdda5;
#             color:  #000000;
#         }    #T_251e2826_3749_11ec_8222_784f4383c434row13_col0 {
#             background-color:  #aedea7;
#             color:  #000000;
#         }    #T_251e2826_3749_11ec_8222_784f4383c434row14_col0 {
#             background-color:  #b0dfaa;
#             color:  #000000;
#         }    #T_251e2826_3749_11ec_8222_784f4383c434row15_col0 {
#             background-color:  #b5e1ae;
#             color:  #000000;
#         }    #T_251e2826_3749_11ec_8222_784f4383c434row16_col0 {
#             background-color:  #bae3b3;
#             color:  #000000;
#         }    #T_251e2826_3749_11ec_8222_784f4383c434row17_col0 {
#             background-color:  #bee5b8;
#             color:  #000000;
#         }    #T_251e2826_3749_11ec_8222_784f4383c434row18_col0 {
#             background-color:  #c1e6ba;
#             color:  #000000;
#         }    #T_251e2826_3749_11ec_8222_784f4383c434row19_col0 {
#             background-color:  #c8e9c1;
#             color:  #000000;
#         }    #T_251e2826_3749_11ec_8222_784f4383c434row20_col0 {
#             background-color:  #c9eac2;
#             color:  #000000;
#         }    #T_251e2826_3749_11ec_8222_784f4383c434row21_col0 {
#             background-color:  #caeac3;
#             color:  #000000;
#         }    #T_251e2826_3749_11ec_8222_784f4383c434row22_col0 {
#             background-color:  #cbeac4;
#             color:  #000000;
#         }    #T_251e2826_3749_11ec_8222_784f4383c434row23_col0 {
#             background-color:  #cbeac4;
#             color:  #000000;
#         }    #T_251e2826_3749_11ec_8222_784f4383c434row24_col0 {
#             background-color:  #cbeac4;
#             color:  #000000;
#         }    #T_251e2826_3749_11ec_8222_784f4383c434row25_col0 {
#             background-color:  #cbeac4;
#             color:  #000000;
#         }    #T_251e2826_3749_11ec_8222_784f4383c434row26_col0 {
#             background-color:  #cbebc5;
#             color:  #000000;
#         }    #T_251e2826_3749_11ec_8222_784f4383c434row27_col0 {
#             background-color:  #cdecc7;
#             color:  #000000;
#         }    #T_251e2826_3749_11ec_8222_784f4383c434row28_col0 {
#             background-color:  #ceecc8;
#             color:  #000000;
#         }    #T_251e2826_3749_11ec_8222_784f4383c434row29_col0 {
#             background-color:  #cfecc9;
#             color:  #000000;
#         }    #T_251e2826_3749_11ec_8222_784f4383c434row30_col0 {
#             background-color:  #cfecc9;
#             color:  #000000;
#         }    #T_251e2826_3749_11ec_8222_784f4383c434row31_col0 {
#             background-color:  #d0edca;
#             color:  #000000;
#         }    #T_251e2826_3749_11ec_8222_784f4383c434row32_col0 {
#             background-color:  #d1edcb;
#             color:  #000000;
#         }    #T_251e2826_3749_11ec_8222_784f4383c434row33_col0 {
#             background-color:  #d3eecd;
#             color:  #000000;
#         }    #T_251e2826_3749_11ec_8222_784f4383c434row34_col0 {
#             background-color:  #d5efcf;
#             color:  #000000;
#         }    #T_251e2826_3749_11ec_8222_784f4383c434row35_col0 {
#             background-color:  #d6efd0;
#             color:  #000000;
#         }    #T_251e2826_3749_11ec_8222_784f4383c434row36_col0 {
#             background-color:  #d6efd0;
#             color:  #000000;
#         }    #T_251e2826_3749_11ec_8222_784f4383c434row37_col0 {
#             background-color:  #d8f0d2;
#             color:  #000000;
#         }    #T_251e2826_3749_11ec_8222_784f4383c434row38_col0 {
#             background-color:  #dbf1d6;
#             color:  #000000;
#         }    #T_251e2826_3749_11ec_8222_784f4383c434row39_col0 {
#             background-color:  #e5f5e0;
#             color:  #000000;
#         }    #T_251e2826_3749_11ec_8222_784f4383c434row40_col0 {
#             background-color:  #e5f5e0;
#             color:  #000000;
#         }    #T_251e2826_3749_11ec_8222_784f4383c434row41_col0 {
#             background-color:  #f4fbf2;
#             color:  #000000;
#         }    #T_251e2826_3749_11ec_8222_784f4383c434row42_col0 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }</style><table id="T_251e2826_3749_11ec_8222_784f4383c434" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >target</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_251e2826_3749_11ec_8222_784f4383c434level0_row0" class="row_heading level0 row0" >target</th>
#                         <td id="T_251e2826_3749_11ec_8222_784f4383c434row0_col0" class="data row0 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_251e2826_3749_11ec_8222_784f4383c434level0_row1" class="row_heading level0 row1" >weeks_worked</th>
#                         <td id="T_251e2826_3749_11ec_8222_784f4383c434row1_col0" class="data row1 col0" >0.464232</td>
#             </tr>
#             <tr>
#                         <th id="T_251e2826_3749_11ec_8222_784f4383c434level0_row2" class="row_heading level0 row2" >num_emp</th>
#                         <td id="T_251e2826_3749_11ec_8222_784f4383c434row2_col0" class="data row2 col0" >0.388822</td>
#             </tr>
#             <tr>
#                         <th id="T_251e2826_3749_11ec_8222_784f4383c434level0_row3" class="row_heading level0 row3" >det_ind_code</th>
#                         <td id="T_251e2826_3749_11ec_8222_784f4383c434row3_col0" class="data row3 col0" >0.343944</td>
#             </tr>
#             <tr>
#                         <th id="T_251e2826_3749_11ec_8222_784f4383c434level0_row4" class="row_heading level0 row4" >fam_under_18</th>
#                         <td id="T_251e2826_3749_11ec_8222_784f4383c434row4_col0" class="data row4 col0" >0.293217</td>
#             </tr>
#             <tr>
#                         <th id="T_251e2826_3749_11ec_8222_784f4383c434level0_row5" class="row_heading level0 row5" >sex</th>
#                         <td id="T_251e2826_3749_11ec_8222_784f4383c434row5_col0" class="data row5 col0" >0.284837</td>
#             </tr>
#             <tr>
#                         <th id="T_251e2826_3749_11ec_8222_784f4383c434level0_row6" class="row_heading level0 row6" >vet_benefits</th>
#                         <td id="T_251e2826_3749_11ec_8222_784f4383c434row6_col0" class="data row6 col0" >0.273264</td>
#             </tr>
#             <tr>

# %%
# Correlation tes
sns.heatmap(clean_X.corr(),annot=False,cmap='RdYlGn') 
fig=plt.gcf()
fig.set_size_inches(20,16)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
clean_X = clean_X.drop(columns = ['target','id'])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(clean_X, Y, test_size=0.2, random_state=77)

# %%
from sklearn.model_selection import cross_val_score
from sklearn import metrics
def cross_val(model):
    pred = cross_val_score(model, X, Y, cv=10)
    return pred.mean()

def print_evaluate(true, predicted):  
    mae = metrics.mean_absolute_error(true, predicted)
    mse = metrics.mean_squared_error(true, predicted)
    rmse = np.sqrt(metrics.mean_squared_error(true, predicted))
    r2_square = metrics.r2_score(true, predicted)
    print('MAE:', mae)
    print('MSE:', mse)
    print('RMSE:', rmse)
    print('R2 Square', r2_square)
    print('__________________________________')
    
def evaluate(true, predicted):
    mae = metrics.mean_absolute_error(true, predicted)
    mse = metrics.mean_squared_error(true, predicted)
    rmse = np.sqrt(metrics.mean_squared_error(true, predicted))
    r2_square = metrics.r2_score(true, predicted)
    return mae, mse, rmse, r2_square

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

pipeline = Pipeline([
    ('std_scalar', StandardScaler())
])

X_train = pipeline.fit_transform(X_train)
X_test = pipeline.transform(X_test)

# %%
import xgboost as xgb

# %%
X_train
# Out:
#        age  class_worker  det_ind_code  det_occ_code  education  \
# 35640   74             3             0             0          5
# 41560   67             3             0             0         16
# 51851   37             7            44            12         16
# 22338    2             3             0             0         10
# 54554   25             4            40            32         16
# ...    ...           ...           ...           ...        ...
# 42277   29             4            37             2          8
# 18667    3             3             0             0         10
# 59348    5             3             0             0         10
# 8799    43             4            32            18         12
# 47831   37             4            37            15          9
#
#        wage_per_hour  hs_college  marital_stat  major_ind_code  \
# 35640              0           2             2              14
# 41560              0           2             0              14
# 51851              0           2             0              20
# 22338              0           2             4              14
# 54554              0           2             4               6
# ...              ...         ...           ...             ...
# 42277              0           2             2               2
# 18667              0           2             4              14
# 59348              0           2             4              14
# 8799               0           2             2              23
# 47831              0           2             2               2
#
#        major_occ_code  ...  fam_under_18  country_father  country_mother  \
# 35640               6  ...             4              40              40
# 41560               6  ...             4              40              40
# 51851              10  ...             4              40              40
# 22338               6  ...             2              40              40
# 54554               7  ...             4              40              40
# ...               ...  ...           ...             ...             ...
# 42277               2  ...             4              40              40
# 18667               6  ...             0              40              40
# 59348               6  ...             2              40              40
# 8799               12  ...             4              40              40
# 47831              13  ...             4               0               0
#
#        country_self  citizenship  own_or_self  vet_question  vet_benefits  \
# 35640            40            4            0             1             2
# 41560            40            4            0             1             2
# 51851            40            4            0             1             2
# 22338            40            4            0             1             0
# 54554            40            4            0             1             2
# ...             ...          ...          ...           ...           ...
# 42277            40            4            1             1             2
# 18667            40            4            0             1             0
# 59348            40            4            0             1             0
# 8799             40            4            0             1             2
# 47831             0            1            1             1             2
#
#        weeks_worked  year
# 35640             0    94
# 41560             0    95
# 51851            40    94
# 22338             0    95
# 54554            52    94
# ...             ...   ...
# 42277            52    94
# 18667             0    94
# 59348             0    95
# 8799             52    95
# 47831            52    94
#
# [47814 rows x 41 columns]

# %%
y_train.to_numpy()
# Out:
# array([0, 0, 0, ..., 0, 1, 1])

# %%
X_train.to_numpy()
# Out:
# (47814, 41)

# %%
params = {
    'booster': 'gbtree',
    'objective': 'multi:softmax',
    'num_class': 3,
    'gamma': 0.1,
    'max_depth': 6,
    'lambda': 2,
    'subsample': 0.7,
    'colsample_bytree': 0.7,
    'min_child_weight': 3,
    'silent': 1,
    'eta': 0.1,
    'seed': 1000,
    'nthread': 4,
}

plst = list(params.items())


dtrain = xgb.DMatrix(X_train.to_numpy(), y_train.to_numpy())
num_rounds = 500
model = xgb.train(plst, dtrain, num_rounds)


dtest = xgb.DMatrix(X_test.to_numpy())
ans = model.predict(dtest)
# Out:
# [01:35:02] WARNING: /Users/travis/build/dmlc/xgboost/src/learner.cc:576:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [01:35:02] WARNING: /Users/travis/build/dmlc/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softmax' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
cnt1 = 0
cnt2 = 0
for i in range(len(y_test)):
    if ans[i] == y_test.to_numpy()[i]:
        cnt1 += 1
    else:
        cnt2 += 1

print("Accuracy: %.2f %% " % (100 * cnt1 / (cnt1 + cnt2)))
print('AUC score',roc_auc_score(y_test.to_numpy(), ans))


plot_importance(model)
plt.show()
# Out:
# Accuracy: 89.79 %
# AUC score 0.8567715458276334

# %%
dtest = xgb.DMatrix(clean_test_X.to_numpy())
ans = model.predict(dtest)

# %%
sample = pd.read_csv('sample_submission.csv')

# %%
sample['income']=[int(label) for label in ans]

# %%
sample.to_csv('output.csv',index=False)

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression(normalize=True)
lin_reg.fit(X_train,y_train)
# Out:
# LinearRegression(normalize=True)

# %%
coeff_df = pd.DataFrame(lin_reg.coef_,clean_X.columns, columns=['Coefficient'])
coeff_df
# Out:
#                 Coefficient
# MS SubClass     2697.818554
# MS Zoning      -2877.469711
# Lot Frontage     502.247910
# Lot Area       -1585.684036
# Street           877.562574
# ...                     ...
# Misc Val       -1344.854363
# Mo Sold          625.488734
# Yr Sold           44.696856
# Sale Type       -732.762455
# Sale Condition  2271.812038
#
# [74 rows x 1 columns]

# %%
pred = lin_reg.predict(X_test)
pd.DataFrame({'True Values': y_test, 'Predicted Values': pred}).plot.scatter(x='True Values', y='Predicted Values')

# %%
pd.DataFrame({'Error Values': (y_test - pred)}).plot.kde()

# %%
test_pred = lin_reg.predict(X_test)
train_pred = lin_reg.predict(X_train)

print('Test set evaluation:\n_____________________________________')
print_evaluate(y_test, test_pred)
print('Train set evaluation:\n_____________________________________')
print_evaluate(y_train, train_pred)
# Out:
# Test set evaluation:
# _____________________________________
# MAE: 18783.62199985962
# MSE: 601530304.9080608
# RMSE: 24526.114753626607
# R2 Square 0.8102364637203231
# __________________________________
# Train set evaluation:
# _____________________________________
# MAE: 16699.374766363457
# MSE: 470588878.76457185
# RMSE: 21693.060613121695
# R2 Square 0.8636902327818822
# __________________________________

# %% [markdown]
# ## Ridge Linear Regression

# %%
from sklearn.linear_model import Ridge

model = Ridge(alpha=100, solver='cholesky', tol=0.0001, random_state=42)
model.fit(X_train, y_train)
pred = model.predict(X_test)

test_pred = model.predict(X_test)
train_pred = model.predict(X_train)

print('Test set evaluation:\n_____________________________________')
print_evaluate(y_test, test_pred)
print('====================================')
print('Train set evaluation:\n_____________________________________')
print_evaluate(y_train, train_pred)
# Out:
# Test set evaluation:
# _____________________________________
# MAE: 18480.705117781312
# MSE: 591229220.0698797
# RMSE: 24315.20553213317
# R2 Square 0.813486125907682
# __________________________________
# ====================================
# Train set evaluation:
# _____________________________________
# MAE: 16713.334605255666
# MSE: 476163368.76755583
# RMSE: 21821.1679056726
# R2 Square 0.8620755379411088
# __________________________________

# %% [markdown]
# ## Lasso Linear Regression

# %%
from sklearn.linear_model import Lasso

model = Lasso(alpha=0.1, 
              precompute=True, 
#               warm_start=True, 
              positive=True, 
              selection='random',
              random_state=42)
model.fit(X_train, y_train)

test_pred = model.predict(X_test)
train_pred = model.predict(X_train)

print('Test set evaluation:\n_____________________________________')
print_evaluate(y_test, test_pred)
print('====================================')
print('Train set evaluation:\n_____________________________________')
print_evaluate(y_train, train_pred)
# Out:
# Test set evaluation:
# _____________________________________
# MAE: 19554.09307068542
# MSE: 646637606.5291348
# RMSE: 25429.07010744071
# R2 Square 0.7960065554383833
# __________________________________
# ====================================
# Train set evaluation:
# _____________________________________
# MAE: 19544.45153125923
# MSE: 639079582.6836208
# RMSE: 25280.023391674717
# R2 Square 0.814885576178188
# __________________________________

# %%
sample_pred = lin_reg.predict(X_sample)

# %%
sample = pd.read_csv("sample.csv")

# %%
sample['SalePrice'] = np.rint(sample_pred)

# %%
sample.to_csv('output.csv',index=False)

# %%
sample
# Out:
#         ID  SalePrice
# 0     1758    68501.0
# 1     1759   180870.0
# 2     1760   189538.0
# 3     1761   110132.0
# 4     1762   263334.0
# ...    ...        ...
# 1167  2925   139769.0
# 1168  2926   116984.0
# 1169  2927   239737.0
# 1170  2928   263681.0
# 1171  2929   275293.0
#
# [1172 rows x 2 columns]
